# %%
# !jupyter nbextension enable --py widgetsnbextension

# %%
from common import *

# Load data
directory_path = '../data'
output_dir='./models/clustering'
bundle_size=30
step_size=5
max_files_per_batch=5
max_samples_clustering=10000
cluster_methods=['kmeans', 'gmm']
use_gpu=True

# %%
# Create output directory
os.makedirs(output_dir, exist_ok=True)

# Step 1: Load and preprocess data
print("\nStep 1: Loading EEG data...")
if os.path.isdir(directory_path):
    file_dfs, _ = load_eeg_data(directory_path=directory_path)
else:
    file_dfs, _ = load_eeg_data(single_file=directory_path)

# Step 2: Preprocess and engineer features
print("\nStep 2: Preprocessing and feature engineering...")
processed_dfs = {}

# Process files in batches to save memory
file_ids = list(file_dfs.keys())

for batch_start in range(0, len(file_ids), max_files_per_batch):
    batch_end = min(batch_start + max_files_per_batch, len(file_ids))
    batch_file_ids = file_ids[batch_start:batch_end]
    
    print(f"  Processing files {batch_start+1}-{batch_end} of {len(file_ids)}")
    
    for file_id in batch_file_ids:
        # Preprocess
        df_clean = preprocess_eeg_data(file_dfs[file_id])
        
        # Engineer features
        df_features = engineer_eeg_features(df_clean)
        
        processed_dfs[file_id] = df_features
        
        # Remove original dataframe to save memory
        del file_dfs[file_id]
    
    # Force garbage collection
    gc.collect()

# Step 3: Create bundles and save to disk
print("\nStep 3: Creating time series bundles and saving to disk...")
metadata, bundle_info = create_coherent_time_series_bundles_disk(
    file_dfs=processed_dfs,
    evenly_spaced_samples=10,       # Get exactly 10 evenly spaced samples per window
    time_window_seconds=1,          # Each window is 5 seconds
    step_time_seconds=1,            # Slide window by 2.5 seconds each step
    max_memory_mb=500,              # Target maximum memory usage of 500MB
    chunk_size=100,                 # Process 100 windows at a time
    output_dir='./eeg_bundles'      # Save bundles here
)
# Out:
# Step 1: Loading EEG data...
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:883: DtypeWarning: Columns (40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Loaded 30 files with 6947837 total rows
#
# Step 2: Preprocessing and feature engineering...
#   Processing files 1-5 of 30
# Warning: Dropping 215 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 108120
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 48 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 75660
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 128 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 129036
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 146 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 308172
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 127 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 291576
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
#   Processing files 6-10 of 30
# Warning: Dropping 220 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 291828
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 84 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 212280
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 174 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 288996
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 44 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 211128
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 297 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 422724
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
#   Processing files 11-15 of 30
# Warning: Dropping 326 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 552804
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 324 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 359796
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 95 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 338652
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 244 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 441108
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 45 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 249084
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
#   Processing files 16-20 of 30
# Warning: Dropping 44 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 78960
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 67 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 84660
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 190 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 171408
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 81 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 203040
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 55 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 88944
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
#   Processing files 21-25 of 30
# Warning: Dropping 47 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 140976
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 76 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 128532
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 52 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 259068
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 78 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 235584
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 109 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 431004
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:970: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_clean[column].fillna(median_value, inplace=True)
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
#   Processing files 26-30 of 30
# Warning: Dropping 62 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 130008
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 44 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 116664
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 33 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 100680
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 49 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 125880
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Warning: Dropping 293 rows with invalid timestamps
# Successfully converted timestamps. Remaining rows: 367668
# c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\helpers.py:1054: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_features = df_features.fillna(method='ffill').fillna(method='bfill')
# Step 3: Creating time series bundles and saving to disk...
#
# Processing files 1-5 of 30
#   Processing file: museMonitor_2024-06-02--09-47-17_5812437961079996628.csv
#     Creating 422 evenly spaced sample bundles from museMonitor_2024-06-02--09-47-17_5812437961079996628.csv
#     Time range: 422.2 seconds, Window: 1s, Step: 1s
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
# ...
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#     Sample array shape: (10, 83), features: 83
#
# Created 18320 bundles in 1338 batch files
# Metadata saved to ./eeg_bundles\bundle_metadata.csv

# %%
# Clear memory
del processed_dfs
gc.collect()
# Out:
# 0

# %%
import os
import pickle
import pandas as pd
output_dir='./models/clustering'
# Path to the directory where your bundles are stored
bundles_dir = os.path.join(output_dir, 'bundles')

# Try to load bundle_info from pickle if it exists
bundle_info_path = os.path.join(bundles_dir, 'bundle_info.pkl')
if os.path.exists(bundle_info_path):
    with open(bundle_info_path, 'rb') as f:
        bundle_info = pickle.load(f)
    print(f"Loaded bundle_info from {bundle_info_path}")
else:
    # If not found, reconstruct from metadata
    metadata_path = os.path.join(bundles_dir, 'bundle_metadata.csv')
    if not os.path.exists(metadata_path):
        metadata_path = os.path.join(bundles_dir, 'metadata.csv')  # Alternative name
    
    if os.path.exists(metadata_path):
        metadata_df = pd.read_csv(metadata_path)
        
        # Count batch files
        batch_files = [f for f in os.listdir(bundles_dir) if f.startswith('bundle_batch_') and f.endswith('.npy')]
        total_batches = len(batch_files)
        
        # Reconstruct bundle_info
        bundle_info = {
            'output_dir': bundles_dir,
            'metadata_path': metadata_path,
            'total_bundles': len(metadata_df),
            'total_batches': total_batches,
            'bundle_size': metadata_df['end_index'].iloc[0] - metadata_df['start_index'].iloc[0] + 1 if len(metadata_df) > 0 else 30,
            'step_size': metadata_df['start_index'].iloc[1] - metadata_df['start_index'].iloc[0] if len(metadata_df) > 1 else 15
        }
        print(f"Reconstructed bundle_info from metadata")
    else:
        raise FileNotFoundError(f"Could not find bundle metadata at {metadata_path}")

# Print some info to verify
print(f"Total bundles: {bundle_info['total_bundles']}")
print(f"Total batches: {bundle_info['total_batches']}")
print(f"Bundle size: {bundle_info['bundle_size']}")
# Out:
# Loaded bundle_info from ./models/clustering\bundles\bundle_info.pkl
# Total bundles: 454644
# Total batches: 459
# Bundle size: 30

# %%
# Step 4: Normalize bundles
print("\nStep 4: Normalizing bundles on disk...")
bundle_info = normalize_bundles_disk(
    bundle_info=bundle_info,
    normalization='per_feature'
)
# Out:
# Step 4: Normalizing bundles on disk...
#
# First pass: Calculating statistics...
# Calculating statistics: 100%|██████████| 18/18 [00:02<00:00,  8.12it/s]
# Second pass: Normalizing and saving...
# Normalizing: 100%|██████████| 18/18 [00:02<00:00,  8.33it/s]

# %%
# Step 5: Cluster a subset of the data
print("\nStep 5: Clustering a subset of the data...")
clustering_results = memory_efficient_clustering(
    bundle_info=bundle_info,
    max_samples=400000,
    methods=cluster_methods,
    use_gpu=use_gpu
)
# Out:
# Step 5: Clustering a subset of the data...
#
# Performing memory-efficient clustering using max 400000 samples...
# Using 27108 bundles for clustering
# Loaded batch file 0 with shape (1220, 10, 0)
# Loaded batch file 1 with shape (1205, 10, 0)
# Loaded batch file 2 with shape (1138, 10, 0)
# Loaded batch file 3 with shape (1139, 10, 0)
# Loaded batch file 4 with shape (1957, 10, 0)
# Loaded batch file 5 with shape (2476, 10, 0)
# Loaded batch file 6 with shape (2159, 10, 0)
# Loaded batch file 7 with shape (1405, 10, 0)
# Loaded batch file 8 with shape (1322, 10, 0)
# Loaded batch file 9 with shape (1722, 10, 0)
# Loaded batch file 10 with shape (973, 10, 0)
# Loaded batch file 11 with shape (1308, 10, 0)
# Loaded batch file 12 with shape (1140, 10, 0)
# Loaded batch file 13 with shape (1049, 10, 0)
# Loaded batch file 14 with shape (1011, 10, 0)
# Loaded batch file 15 with shape (2602, 10, 0)
# Loaded batch file 16 with shape (1355, 10, 0)
# Loaded batch file 17 with shape (1927, 10, 0)
# Data shape for clustering: (27108, 0)
#
# Running KMEANS clustering...
#   No module named 'cuml'. Falling back to CPU implementation.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Step 5: Cluster a subset of the data
#       2 print("\nStep 5: Clustering a subset of the data...")
# ----> 3 clustering_results = memory_efficient_clustering(
#       4     bundle_info=bundle_info,
#       5     max_samples=400000,
#       6     methods=cluster_methods,
#       7     use_gpu=use_gpu
#       8 )
#
# File c:\Users\Huai\Documents\GitHub\EEG-classification\training\common\unsupervised.py:659, in memory_efficient_clustering(bundle_info, max_samples, methods, n_clusters, use_gpu)
#     656 if method == 'kmeans':
#     657     # K-means with k=n_clusters
#     658     clustering = KMeans(n_clusters=n_clusters, random_state=42)
# --> 659     labels = clustering.fit_predict(X_flat)
#     660     print(f"  CPU K-means completed in {time.time() - cpu_start_time:.2f} seconds")
#     662 elif method == 'gmm':
#     663     # Gaussian Mixture Model
#
# File c:\Users\Huai\miniconda3\envs\eeg\Lib\site-packages\sklearn\cluster\_kmeans.py:1064, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1041 def fit_predict(self, X, y=None, sample_weight=None):
#    1042     """Compute cluster centers and predict cluster index for each sample.
#    1043
#    1044     Convenience method; equivalent to calling fit(X) followed by
#    (...)   1062         Index of the cluster each sample belongs to.
#    1063     """
# -> 1064     return self.fit(X, sample_weight=sample_weight).labels_
#
# File c:\Users\Huai\miniconda3\envs\eeg\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Huai\miniconda3\envs\eeg\Lib\site-packages\sklearn\cluster\_kmeans.py:1454, in KMeans.fit(self, X, y, sample_weight)
#    1426 @_fit_context(prefer_skip_nested_validation=True)
#    1427 def fit(self, X, y=None, sample_weight=None):
#    1428     """Compute k-means clustering.
#    1429
#    1430     Parameters
#    (...)   1452         Fitted estimator.
#    1453     """
# -> 1454     X = validate_data(
#    1455         self,
#    1456         X,
#    1457         accept_sparse="csr",
#    1458         dtype=[np.float64, np.float32],
#    1459         order="C",
#    1460         copy=self.copy_x,
#    1461         accept_large_sparse=False,
#    1462     )
#    1464     self._check_params_vs_input(X)
#    1466     random_state = check_random_state(self.random_state)
#
# File c:\Users\Huai\miniconda3\envs\eeg\Lib\site-packages\sklearn\utils\validation.py:2944, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942         out = X, y
#    2943 elif not no_val_X and no_val_y:
# -> 2944     out = check_array(X, input_name="X", **check_params)
#    2945 elif no_val_X and not no_val_y:
#    2946     out = _check_y(y, **check_params)
#
# File c:\Users\Huai\miniconda3\envs\eeg\Lib\site-packages\sklearn\utils\validation.py:1139, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1137     n_features = array.shape[1]
#    1138     if n_features < ensure_min_features:
# -> 1139         raise ValueError(
#    1140             "Found array with %d feature(s) (shape=%s) while"
#    1141             " a minimum of %d is required%s."
#    1142             % (n_features, array.shape, ensure_min_features, context)
#    1143         )
#    1145 if ensure_non_negative:
#    1146     whom = input_name
#
# ValueError: Found array with 0 feature(s) (shape=(27108, 0)) while a minimum of 1 is required by KMeans.

# %%
# Step 6: Predict clusters for all bundles
print("\nStep 6: Predicting clusters for all bundles...")
bundle_clusters = predict_clusters_disk(
    bundle_info=bundle_info,
    clustering_results=clustering_results,
    output_file=os.path.join(output_dir, 'bundle_clusters.json')
)

# Step 7: Analyze results
print("\nStep 7: Analyzing cluster characteristics...")
best_method = max(
    clustering_results.keys(),
    key=lambda m: (
        clustering_results[m]['eval_metrics']['silhouette_score'] 
        if clustering_results[m]['eval_metrics']['silhouette_score'] is not None 
        else -1
    )
)

# Count bundles per cluster
cluster_counts = {}
for cluster in bundle_clusters.values():
    if cluster not in cluster_counts:
        cluster_counts[cluster] = 0
    cluster_counts[cluster] += 1

print(f"\nCluster distribution from {best_method}:")
for cluster, count in sorted(cluster_counts.items()):
    print(f"  Cluster {cluster}: {count} bundles ({count/len(bundle_clusters)*100:.1f}%)")

results =  bundle_info, clustering_results, bundle_clusters
# Out:
# Step 6: Predicting clusters for all bundles...
#
# Using kmeans clustering model to predict all clusters
# Predicting clusters for 454644 bundles...
# Loaded batch file 0 with shape (1000, 30, 83)
# Loaded batch file 1 with shape (1000, 30, 83)
# Loaded batch file 2 with shape (1000, 30, 83)
# Loaded batch file 3 with shape (1000, 30, 83)
# Loaded batch file 4 with shape (1000, 30, 83)
# Loaded batch file 5 with shape (1000, 30, 83)
# Loaded batch file 6 with shape (1000, 30, 83)
# Loaded batch file 7 with shape (1000, 30, 83)
# Loaded batch file 8 with shape (1000, 30, 83)
# Loaded batch file 9 with shape (1000, 30, 83)
#   Processed 10000/454644 bundles
# Loaded batch file 10 with shape (1000, 30, 83)
# Loaded batch file 11 with shape (1000, 30, 83)
# Loaded batch file 12 with shape (1000, 30, 83)
# Loaded batch file 13 with shape (1000, 30, 83)
# Loaded batch file 14 with shape (1000, 30, 83)
# Loaded batch file 15 with shape (1000, 30, 83)
# Loaded batch file 16 with shape (1000, 30, 83)
# Loaded batch file 17 with shape (1000, 30, 83)
# Loaded batch file 18 with shape (1000, 30, 83)
# Loaded batch file 19 with shape (1000, 30, 83)
#   Processed 20000/454644 bundles
# Loaded batch file 20 with shape (1000, 30, 83)
# Loaded batch file 21 with shape (1000, 30, 83)
# Loaded batch file 22 with shape (1000, 30, 83)
# Loaded batch file 23 with shape (1000, 30, 83)
# Loaded batch file 24 with shape (1000, 30, 83)
# Loaded batch file 25 with shape (1000, 30, 83)
# Loaded batch file 26 with shape (1000, 30, 83)
# Loaded batch file 27 with shape (1000, 30, 83)
# Loaded batch file 28 with shape (1000, 30, 83)
# Loaded batch file 29 with shape (1000, 30, 83)
#   Processed 30000/454644 bundles
# Loaded batch file 30 with shape (1000, 30, 83)
# Loaded batch file 31 with shape (1000, 30, 83)
# Loaded batch file 32 with shape (1000, 30, 83)
# Loaded batch file 33 with shape (1000, 30, 83)
# Loaded batch file 34 with shape (1000, 30, 83)
# Loaded batch file 35 with shape (1000, 30, 83)
# Loaded batch file 36 with shape (1000, 30, 83)
# Loaded batch file 37 with shape (1000, 30, 83)
# Loaded batch file 38 with shape (1000, 30, 83)
# Loaded batch file 39 with shape (1000, 30, 83)
#   Processed 40000/454644 bundles
# Loaded batch file 40 with shape (1000, 30, 83)
# Loaded batch file 41 with shape (1000, 30, 83)
# Loaded batch file 42 with shape (1000, 30, 83)
# Loaded batch file 43 with shape (1000, 30, 83)
# Loaded batch file 44 with shape (1000, 30, 83)
# Loaded batch file 45 with shape (1000, 30, 83)
# Loaded batch file 46 with shape (1000, 30, 83)
# Loaded batch file 47 with shape (1000, 30, 83)
# Loaded batch file 48 with shape (1000, 30, 83)
# Loaded batch file 49 with shape (1000, 30, 83)
#   Processed 50000/454644 bundles
# Loaded batch file 50 with shape (1000, 30, 83)
# Loaded batch file 51 with shape (1000, 30, 83)
# Loaded batch file 52 with shape (1000, 30, 83)
# Loaded batch file 53 with shape (1000, 30, 83)
# Loaded batch file 54 with shape (1000, 30, 83)
# Loaded batch file 55 with shape (1000, 30, 83)
# Loaded batch file 56 with shape (1000, 30, 83)
# Loaded batch file 57 with shape (1000, 30, 83)
# Loaded batch file 58 with shape (1000, 30, 83)
# Loaded batch file 59 with shape (1000, 30, 83)
#   Processed 60000/454644 bundles
# Loaded batch file 60 with shape (800, 30, 83)
# Loaded batch file 61 with shape (1000, 30, 83)
# Loaded batch file 62 with shape (1000, 30, 83)
# Loaded batch file 63 with shape (1000, 30, 83)
# Loaded batch file 64 with shape (1000, 30, 83)
# Loaded batch file 65 with shape (1000, 30, 83)
# Loaded batch file 66 with shape (1000, 30, 83)
# Loaded batch file 67 with shape (1000, 30, 83)
# Loaded batch file 68 with shape (1000, 30, 83)
# Loaded batch file 69 with shape (1000, 30, 83)
# Loaded batch file 70 with shape (1000, 30, 83)
#   Processed 70000/454644 bundles
# Loaded batch file 71 with shape (1000, 30, 83)
# Loaded batch file 72 with shape (1000, 30, 83)
# Loaded batch file 73 with shape (1000, 30, 83)
# Loaded batch file 74 with shape (1000, 30, 83)
# Loaded batch file 75 with shape (1000, 30, 83)
# Loaded batch file 76 with shape (1000, 30, 83)
# Loaded batch file 77 with shape (1000, 30, 83)
# Loaded batch file 78 with shape (1000, 30, 83)
# Loaded batch file 79 with shape (1000, 30, 83)
# Loaded batch file 80 with shape (1000, 30, 83)
#   Processed 80000/454644 bundles
# Loaded batch file 81 with shape (1000, 30, 83)
# Loaded batch file 82 with shape (1000, 30, 83)
# Loaded batch file 83 with shape (1000, 30, 83)
# Loaded batch file 84 with shape (1000, 30, 83)
# Loaded batch file 85 with shape (1000, 30, 83)
# Loaded batch file 86 with shape (1000, 30, 83)
# Loaded batch file 87 with shape (1000, 30, 83)
# Loaded batch file 88 with shape (1000, 30, 83)
# Loaded batch file 89 with shape (1000, 30, 83)
# Loaded batch file 90 with shape (1000, 30, 83)
#   Processed 90000/454644 bundles
# Loaded batch file 91 with shape (1000, 30, 83)
# Loaded batch file 92 with shape (1000, 30, 83)
# Loaded batch file 93 with shape (1000, 30, 83)
# Loaded batch file 94 with shape (1000, 30, 83)
# Loaded batch file 95 with shape (1000, 30, 83)
# Loaded batch file 96 with shape (1000, 30, 83)
# Loaded batch file 97 with shape (1000, 30, 83)
# Loaded batch file 98 with shape (1000, 30, 83)
# Loaded batch file 99 with shape (1000, 30, 83)
# Loaded batch file 100 with shape (1000, 30, 83)
#   Processed 100000/454644 bundles
# Loaded batch file 101 with shape (1000, 30, 83)
# Loaded batch file 102 with shape (1000, 30, 83)
# Loaded batch file 103 with shape (1000, 30, 83)
# Loaded batch file 104 with shape (1000, 30, 83)
# Loaded batch file 105 with shape (1000, 30, 83)
# Loaded batch file 106 with shape (1000, 30, 83)
# Loaded batch file 107 with shape (1000, 30, 83)
# Loaded batch file 108 with shape (1000, 30, 83)
# Loaded batch file 109 with shape (1000, 30, 83)
# Loaded batch file 110 with shape (1000, 30, 83)
#   Processed 110000/454644 bundles
# Loaded batch file 111 with shape (1000, 30, 83)
# Loaded batch file 112 with shape (1000, 30, 83)
# Loaded batch file 113 with shape (1000, 30, 83)
# Loaded batch file 114 with shape (1000, 30, 83)
# Loaded batch file 115 with shape (1000, 30, 83)
# Loaded batch file 116 with shape (1000, 30, 83)
# Loaded batch file 117 with shape (1000, 30, 83)
# Loaded batch file 118 with shape (1000, 30, 83)
# Loaded batch file 119 with shape (1000, 30, 83)
# Loaded batch file 120 with shape (1000, 30, 83)
#   Processed 120000/454644 bundles
# Loaded batch file 121 with shape (1000, 30, 83)
# Loaded batch file 122 with shape (1000, 30, 83)
# Loaded batch file 123 with shape (1000, 30, 83)
# Loaded batch file 124 with shape (1000, 30, 83)
# Loaded batch file 125 with shape (1000, 30, 83)
# Loaded batch file 126 with shape (1000, 30, 83)
# Loaded batch file 127 with shape (1000, 30, 83)
# Loaded batch file 128 with shape (1000, 30, 83)
# Loaded batch file 129 with shape (1000, 30, 83)
# Loaded batch file 130 with shape (1000, 30, 83)
#   Processed 130000/454644 bundles
# Loaded batch file 131 with shape (1000, 30, 83)
# Loaded batch file 132 with shape (1000, 30, 83)
# Loaded batch file 133 with shape (1000, 30, 83)
# Loaded batch file 134 with shape (1000, 30, 83)
# Loaded batch file 135 with shape (1000, 30, 83)
# Loaded batch file 136 with shape (1000, 30, 83)
# Loaded batch file 137 with shape (1000, 30, 83)
# Loaded batch file 138 with shape (1000, 30, 83)
# Loaded batch file 139 with shape (1000, 30, 83)
# Loaded batch file 140 with shape (1000, 30, 83)
#   Processed 140000/454644 bundles
# Loaded batch file 141 with shape (1000, 30, 83)
# Loaded batch file 142 with shape (1000, 30, 83)
# Loaded batch file 143 with shape (1000, 30, 83)
# Loaded batch file 144 with shape (1000, 30, 83)
# Loaded batch file 145 with shape (1000, 30, 83)
# Loaded batch file 146 with shape (1000, 30, 83)
# Loaded batch file 147 with shape (1000, 30, 83)
# Loaded batch file 148 with shape (1000, 30, 83)
# Loaded batch file 149 with shape (1000, 30, 83)
# Loaded batch file 150 with shape (1000, 30, 83)
#   Processed 150000/454644 bundles
# Loaded batch file 151 with shape (1000, 30, 83)
# Loaded batch file 152 with shape (1000, 30, 83)
# Loaded batch file 153 with shape (1000, 30, 83)
# Loaded batch file 154 with shape (58, 30, 83)
# Loaded batch file 155 with shape (1000, 30, 83)
# Loaded batch file 156 with shape (1000, 30, 83)
# Loaded batch file 157 with shape (1000, 30, 83)
# Loaded batch file 158 with shape (1000, 30, 83)
# Loaded batch file 159 with shape (1000, 30, 83)
# Loaded batch file 160 with shape (1000, 30, 83)
# Loaded batch file 161 with shape (1000, 30, 83)
#   Processed 160000/454644 bundles
# Loaded batch file 162 with shape (1000, 30, 83)
# Loaded batch file 163 with shape (1000, 30, 83)
# Loaded batch file 164 with shape (1000, 30, 83)
# Loaded batch file 165 with shape (1000, 30, 83)
# Loaded batch file 166 with shape (1000, 30, 83)
# Loaded batch file 167 with shape (1000, 30, 83)
# Loaded batch file 168 with shape (1000, 30, 83)
# Loaded batch file 169 with shape (1000, 30, 83)
# Loaded batch file 170 with shape (1000, 30, 83)
# Loaded batch file 171 with shape (1000, 30, 83)
#   Processed 170000/454644 bundles
# Loaded batch file 172 with shape (1000, 30, 83)
# Loaded batch file 173 with shape (1000, 30, 83)
# Loaded batch file 174 with shape (1000, 30, 83)
# Loaded batch file 175 with shape (1000, 30, 83)
# Loaded batch file 176 with shape (1000, 30, 83)
# Loaded batch file 177 with shape (1000, 30, 83)
# Loaded batch file 178 with shape (1000, 30, 83)
# Loaded batch file 179 with shape (1000, 30, 83)
# Loaded batch file 180 with shape (1000, 30, 83)
# Loaded batch file 181 with shape (1000, 30, 83)
#   Processed 180000/454644 bundles
# Loaded batch file 182 with shape (1000, 30, 83)
# Loaded batch file 183 with shape (1000, 30, 83)
# Loaded batch file 184 with shape (1000, 30, 83)
# Loaded batch file 185 with shape (1000, 30, 83)
# Loaded batch file 186 with shape (1000, 30, 83)
# Loaded batch file 187 with shape (1000, 30, 83)
# Loaded batch file 188 with shape (1000, 30, 83)
# Loaded batch file 189 with shape (1000, 30, 83)
# Loaded batch file 190 with shape (1000, 30, 83)
# Loaded batch file 191 with shape (1000, 30, 83)
#   Processed 190000/454644 bundles
# Loaded batch file 192 with shape (1000, 30, 83)
# Loaded batch file 193 with shape (1000, 30, 83)
# Loaded batch file 194 with shape (1000, 30, 83)
# Loaded batch file 195 with shape (1000, 30, 83)
# Loaded batch file 196 with shape (1000, 30, 83)
# Loaded batch file 197 with shape (1000, 30, 83)
# Loaded batch file 198 with shape (1000, 30, 83)
# Loaded batch file 199 with shape (1000, 30, 83)
# Loaded batch file 200 with shape (1000, 30, 83)
# Loaded batch file 201 with shape (1000, 30, 83)
#   Processed 200000/454644 bundles
# Loaded batch file 202 with shape (1000, 30, 83)
# Loaded batch file 203 with shape (1000, 30, 83)
# Loaded batch file 204 with shape (1000, 30, 83)
# Loaded batch file 205 with shape (1000, 30, 83)
# Loaded batch file 206 with shape (1000, 30, 83)
# Loaded batch file 207 with shape (1000, 30, 83)
# Loaded batch file 208 with shape (1000, 30, 83)
# Loaded batch file 209 with shape (1000, 30, 83)
# Loaded batch file 210 with shape (1000, 30, 83)
# Loaded batch file 211 with shape (1000, 30, 83)
#   Processed 210000/454644 bundles
# Loaded batch file 212 with shape (1000, 30, 83)
# Loaded batch file 213 with shape (1000, 30, 83)
# Loaded batch file 214 with shape (1000, 30, 83)
# Loaded batch file 215 with shape (1000, 30, 83)
# Loaded batch file 216 with shape (1000, 30, 83)
# Loaded batch file 217 with shape (1000, 30, 83)
# Loaded batch file 218 with shape (1000, 30, 83)
# Loaded batch file 219 with shape (1000, 30, 83)
# Loaded batch file 220 with shape (1000, 30, 83)
# Loaded batch file 221 with shape (1000, 30, 83)
#   Processed 220000/454644 bundles
# Loaded batch file 222 with shape (1000, 30, 83)
# Loaded batch file 223 with shape (1000, 30, 83)
# Loaded batch file 224 with shape (1000, 30, 83)
# Loaded batch file 225 with shape (1000, 30, 83)
# Loaded batch file 226 with shape (1000, 30, 83)
# Loaded batch file 227 with shape (1000, 30, 83)
# Loaded batch file 228 with shape (1000, 30, 83)
# Loaded batch file 229 with shape (1000, 30, 83)
# Loaded batch file 230 with shape (1000, 30, 83)
# Loaded batch file 231 with shape (1000, 30, 83)
#   Processed 230000/454644 bundles
# Loaded batch file 232 with shape (1000, 30, 83)
# Loaded batch file 233 with shape (1000, 30, 83)
# Loaded batch file 234 with shape (1000, 30, 83)
# Loaded batch file 235 with shape (1000, 30, 83)
# Loaded batch file 236 with shape (1000, 30, 83)
# Loaded batch file 237 with shape (1000, 30, 83)
# Loaded batch file 238 with shape (1000, 30, 83)
# Loaded batch file 239 with shape (1000, 30, 83)
# Loaded batch file 240 with shape (1000, 30, 83)
# Loaded batch file 241 with shape (1000, 30, 83)
#   Processed 240000/454644 bundles
# Loaded batch file 242 with shape (1000, 30, 83)
# Loaded batch file 243 with shape (1000, 30, 83)
# Loaded batch file 244 with shape (1000, 30, 83)
# Loaded batch file 245 with shape (1000, 30, 83)
# Loaded batch file 246 with shape (1000, 30, 83)
# Loaded batch file 247 with shape (1000, 30, 83)
# Loaded batch file 248 with shape (1000, 30, 83)
# Loaded batch file 249 with shape (1000, 30, 83)
# Loaded batch file 250 with shape (1000, 30, 83)
# Loaded batch file 251 with shape (1000, 30, 83)
#   Processed 250000/454644 bundles
# Loaded batch file 252 with shape (1000, 30, 83)
# Loaded batch file 253 with shape (1000, 30, 83)
# Loaded batch file 254 with shape (1000, 30, 83)
# Loaded batch file 255 with shape (1000, 30, 83)
# Loaded batch file 256 with shape (1000, 30, 83)
# Loaded batch file 257 with shape (1000, 30, 83)
# Loaded batch file 258 with shape (1000, 30, 83)
# Loaded batch file 259 with shape (1000, 30, 83)
# Loaded batch file 260 with shape (1000, 30, 83)
# Loaded batch file 261 with shape (1000, 30, 83)
#   Processed 260000/454644 bundles
# Loaded batch file 262 with shape (1000, 30, 83)
# Loaded batch file 263 with shape (1000, 30, 83)
# Loaded batch file 264 with shape (1000, 30, 83)
# Loaded batch file 265 with shape (1000, 30, 83)
# Loaded batch file 266 with shape (1000, 30, 83)
# Loaded batch file 267 with shape (1000, 30, 83)
# Loaded batch file 268 with shape (1000, 30, 83)
# Loaded batch file 269 with shape (1000, 30, 83)
# Loaded batch file 270 with shape (1000, 30, 83)
# Loaded batch file 271 with shape (1000, 30, 83)
#   Processed 270000/454644 bundles
# Loaded batch file 272 with shape (1000, 30, 83)
# Loaded batch file 273 with shape (1000, 30, 83)
# Loaded batch file 274 with shape (1000, 30, 83)
# Loaded batch file 275 with shape (1000, 30, 83)
# Loaded batch file 276 with shape (1000, 30, 83)
# Loaded batch file 277 with shape (1000, 30, 83)
# Loaded batch file 278 with shape (1000, 30, 83)
# Loaded batch file 279 with shape (1000, 30, 83)
# Loaded batch file 280 with shape (1000, 30, 83)
# Loaded batch file 281 with shape (1000, 30, 83)
#   Processed 280000/454644 bundles
# Loaded batch file 282 with shape (1000, 30, 83)
# Loaded batch file 283 with shape (1000, 30, 83)
# Loaded batch file 284 with shape (129, 30, 83)
# Loaded batch file 285 with shape (1000, 30, 83)
# Loaded batch file 286 with shape (1000, 30, 83)
# Loaded batch file 287 with shape (1000, 30, 83)
# Loaded batch file 288 with shape (1000, 30, 83)
# Loaded batch file 289 with shape (1000, 30, 83)
# Loaded batch file 290 with shape (1000, 30, 83)
# Loaded batch file 291 with shape (1000, 30, 83)
# Loaded batch file 292 with shape (1000, 30, 83)
#   Processed 290000/454644 bundles
# Loaded batch file 293 with shape (1000, 30, 83)
# Loaded batch file 294 with shape (1000, 30, 83)
# Loaded batch file 295 with shape (1000, 30, 83)
# Loaded batch file 296 with shape (1000, 30, 83)
# Loaded batch file 297 with shape (1000, 30, 83)
# Loaded batch file 298 with shape (1000, 30, 83)
# Loaded batch file 299 with shape (1000, 30, 83)
# Loaded batch file 300 with shape (1000, 30, 83)
# Loaded batch file 301 with shape (1000, 30, 83)
# Loaded batch file 302 with shape (1000, 30, 83)
#   Processed 300000/454644 bundles
# Loaded batch file 303 with shape (1000, 30, 83)
# Loaded batch file 304 with shape (1000, 30, 83)
# Loaded batch file 305 with shape (1000, 30, 83)
# Loaded batch file 306 with shape (1000, 30, 83)
# Loaded batch file 307 with shape (1000, 30, 83)
# Loaded batch file 308 with shape (1000, 30, 83)
# Loaded batch file 309 with shape (1000, 30, 83)
# Loaded batch file 310 with shape (1000, 30, 83)
# Loaded batch file 311 with shape (1000, 30, 83)
# Loaded batch file 312 with shape (1000, 30, 83)
#   Processed 310000/454644 bundles
# Loaded batch file 313 with shape (1000, 30, 83)
# Loaded batch file 314 with shape (1000, 30, 83)
# Loaded batch file 315 with shape (1000, 30, 83)
# Loaded batch file 316 with shape (1000, 30, 83)
# Loaded batch file 317 with shape (1000, 30, 83)
# Loaded batch file 318 with shape (1000, 30, 83)
# Loaded batch file 319 with shape (1000, 30, 83)
# Loaded batch file 320 with shape (1000, 30, 83)
# Loaded batch file 321 with shape (1000, 30, 83)
# Loaded batch file 322 with shape (1000, 30, 83)
#   Processed 320000/454644 bundles
# Loaded batch file 323 with shape (1000, 30, 83)
# Loaded batch file 324 with shape (1000, 30, 83)
# Loaded batch file 325 with shape (220, 30, 83)
# Loaded batch file 326 with shape (1000, 30, 83)
# Loaded batch file 327 with shape (1000, 30, 83)
# Loaded batch file 328 with shape (1000, 30, 83)
# Loaded batch file 329 with shape (1000, 30, 83)
# Loaded batch file 330 with shape (1000, 30, 83)
# Loaded batch file 331 with shape (1000, 30, 83)
# Loaded batch file 332 with shape (1000, 30, 83)
#   Processed 330000/454644 bundles
# Loaded batch file 333 with shape (1000, 30, 83)
# Loaded batch file 334 with shape (1000, 30, 83)
# Loaded batch file 335 with shape (1000, 30, 83)
# Loaded batch file 336 with shape (1000, 30, 83)
# Loaded batch file 337 with shape (1000, 30, 83)
# Loaded batch file 338 with shape (1000, 30, 83)
# Loaded batch file 339 with shape (1000, 30, 83)
# Loaded batch file 340 with shape (1000, 30, 83)
# Loaded batch file 341 with shape (1000, 30, 83)
# Loaded batch file 342 with shape (1000, 30, 83)
#   Processed 340000/454644 bundles
# Loaded batch file 343 with shape (1000, 30, 83)
# Loaded batch file 344 with shape (1000, 30, 83)
# Loaded batch file 345 with shape (1000, 30, 83)
# Loaded batch file 346 with shape (1000, 30, 83)
# Loaded batch file 347 with shape (1000, 30, 83)
# Loaded batch file 348 with shape (1000, 30, 83)
# Loaded batch file 349 with shape (1000, 30, 83)
# Loaded batch file 350 with shape (1000, 30, 83)
# Loaded batch file 351 with shape (1000, 30, 83)
# Loaded batch file 352 with shape (1000, 30, 83)
#   Processed 350000/454644 bundles
# Loaded batch file 353 with shape (1000, 30, 83)
# Loaded batch file 354 with shape (1000, 30, 83)
# Loaded batch file 355 with shape (1000, 30, 83)
# Loaded batch file 356 with shape (1000, 30, 83)
# Loaded batch file 357 with shape (1000, 30, 83)
# Loaded batch file 358 with shape (1000, 30, 83)
# Loaded batch file 359 with shape (1000, 30, 83)
# Loaded batch file 360 with shape (1000, 30, 83)
# Loaded batch file 361 with shape (1000, 30, 83)
# Loaded batch file 362 with shape (1000, 30, 83)
#   Processed 360000/454644 bundles
# Loaded batch file 363 with shape (1000, 30, 83)
# Loaded batch file 364 with shape (1000, 30, 83)
# Loaded batch file 365 with shape (1000, 30, 83)
# Loaded batch file 366 with shape (1000, 30, 83)
# Loaded batch file 367 with shape (1000, 30, 83)
# Loaded batch file 368 with shape (1000, 30, 83)
# Loaded batch file 369 with shape (1000, 30, 83)
# Loaded batch file 370 with shape (1000, 30, 83)
# Loaded batch file 371 with shape (1000, 30, 83)
# Loaded batch file 372 with shape (1000, 30, 83)
#   Processed 370000/454644 bundles
# Loaded batch file 373 with shape (1000, 30, 83)
# Loaded batch file 374 with shape (1000, 30, 83)
# Loaded batch file 375 with shape (1000, 30, 83)
# Loaded batch file 376 with shape (1000, 30, 83)
# Loaded batch file 377 with shape (1000, 30, 83)
# Loaded batch file 378 with shape (1000, 30, 83)
# Loaded batch file 379 with shape (1000, 30, 83)
# Loaded batch file 380 with shape (1000, 30, 83)
# Loaded batch file 381 with shape (1000, 30, 83)
# Loaded batch file 382 with shape (1000, 30, 83)
#   Processed 380000/454644 bundles
# Loaded batch file 383 with shape (1000, 30, 83)
# Loaded batch file 384 with shape (1000, 30, 83)
# Loaded batch file 385 with shape (1000, 30, 83)
# Loaded batch file 386 with shape (1000, 30, 83)
# Loaded batch file 387 with shape (1000, 30, 83)
# Loaded batch file 388 with shape (1000, 30, 83)
# Loaded batch file 389 with shape (1000, 30, 83)
# Loaded batch file 390 with shape (1000, 30, 83)
# Loaded batch file 391 with shape (1000, 30, 83)
# Loaded batch file 392 with shape (1000, 30, 83)
#   Processed 390000/454644 bundles
# Loaded batch file 393 with shape (1000, 30, 83)
# Loaded batch file 394 with shape (1000, 30, 83)
# Loaded batch file 395 with shape (1000, 30, 83)
# Loaded batch file 396 with shape (1000, 30, 83)
# Loaded batch file 397 with shape (1000, 30, 83)
# Loaded batch file 398 with shape (1000, 30, 83)
# Loaded batch file 399 with shape (1000, 30, 83)
# Loaded batch file 400 with shape (1000, 30, 83)
# Loaded batch file 401 with shape (401, 30, 83)
# Loaded batch file 402 with shape (1000, 30, 83)
# Loaded batch file 403 with shape (1000, 30, 83)
#   Processed 400000/454644 bundles
# Loaded batch file 404 with shape (1000, 30, 83)
# Loaded batch file 405 with shape (1000, 30, 83)
# Loaded batch file 406 with shape (1000, 30, 83)
# Loaded batch file 407 with shape (1000, 30, 83)
# Loaded batch file 408 with shape (1000, 30, 83)
# Loaded batch file 409 with shape (1000, 30, 83)
# Loaded batch file 410 with shape (1000, 30, 83)
# Loaded batch file 411 with shape (1000, 30, 83)
# Loaded batch file 412 with shape (1000, 30, 83)
# Loaded batch file 413 with shape (1000, 30, 83)
#   Processed 410000/454644 bundles
# Loaded batch file 414 with shape (1000, 30, 83)
# Loaded batch file 415 with shape (1000, 30, 83)
# Loaded batch file 416 with shape (1000, 30, 83)
# Loaded batch file 417 with shape (1000, 30, 83)
# Loaded batch file 418 with shape (1000, 30, 83)
# Loaded batch file 419 with shape (1000, 30, 83)
# Loaded batch file 420 with shape (1000, 30, 83)
# Loaded batch file 421 with shape (1000, 30, 83)
# Loaded batch file 422 with shape (1000, 30, 83)
# Loaded batch file 423 with shape (1000, 30, 83)
#   Processed 420000/454644 bundles
# Loaded batch file 424 with shape (1000, 30, 83)
# Loaded batch file 425 with shape (1000, 30, 83)
# Loaded batch file 426 with shape (1000, 30, 83)
# Loaded batch file 427 with shape (1000, 30, 83)
# Loaded batch file 428 with shape (1000, 30, 83)
# Loaded batch file 429 with shape (1000, 30, 83)
# Loaded batch file 430 with shape (1000, 30, 83)
# Loaded batch file 431 with shape (1000, 30, 83)
# Loaded batch file 432 with shape (1000, 30, 83)
# Loaded batch file 433 with shape (1000, 30, 83)
#   Processed 430000/454644 bundles
# Loaded batch file 434 with shape (1000, 30, 83)
# Loaded batch file 435 with shape (1000, 30, 83)
# Loaded batch file 436 with shape (1000, 30, 83)
# Loaded batch file 437 with shape (1000, 30, 83)
# Loaded batch file 438 with shape (1000, 30, 83)
# Loaded batch file 439 with shape (1000, 30, 83)
# Loaded batch file 440 with shape (1000, 30, 83)
# Loaded batch file 441 with shape (1000, 30, 83)
# Loaded batch file 442 with shape (1000, 30, 83)
# Loaded batch file 443 with shape (1000, 30, 83)
#   Processed 440000/454644 bundles
# Loaded batch file 444 with shape (1000, 30, 83)
# Loaded batch file 445 with shape (1000, 30, 83)
# Loaded batch file 446 with shape (1000, 30, 83)
# Loaded batch file 447 with shape (1000, 30, 83)
# Loaded batch file 448 with shape (1000, 30, 83)
# Loaded batch file 449 with shape (1000, 30, 83)
# Loaded batch file 450 with shape (1000, 30, 83)
# Loaded batch file 451 with shape (1000, 30, 83)
# Loaded batch file 452 with shape (1000, 30, 83)
# Loaded batch file 453 with shape (1000, 30, 83)
#   Processed 450000/454644 bundles
# Loaded batch file 454 with shape (1000, 30, 83)
# Loaded batch file 455 with shape (1000, 30, 83)
# Loaded batch file 456 with shape (1000, 30, 83)
# Loaded batch file 457 with shape (1000, 30, 83)
# Loaded batch file 458 with shape (36, 30, 83)
#   Processed 454644/454644 bundles
#
# Step 7: Analyzing cluster characteristics...
#
# Cluster distribution from kmeans:
#   Cluster 0: 72655 bundles (16.0%)
#   Cluster 1: 381989 bundles (84.0%)

# %%
results
# Out:
# ({'output_dir': './models/clustering\\bundles',
#   'metadata_path': './models/clustering\\bundles\\bundle_metadata.csv',
#   'total_bundles': 454644,
#   'total_batches': 459,
#   'bundle_size': 30,
#   'step_size': 15,
#   'normalized_dir': './models/clustering\\bundles\\normalized',
#   'normalization': 'per_feature',
#   'norm_params': {'mean': array([[0.84725004, 0.75139831, 0.61285558, ..., 0.19036886, 0.01832293,
#            1.00799927],
#           [0.84723915, 0.75133593, 0.61281388, ..., 0.1894901 , 0.01951778,
#            1.00799949],
#           [0.8472173 , 0.7512255 , 0.61278104, ..., 0.18945108, 0.01966462,
#            1.00800118],
#           ...,
#           [0.84728858, 0.75138935, 0.61285356, ..., 0.19036583, 0.01824929,
#            1.0079946 ],
#           [0.84724058, 0.75130768, 0.61282124, ..., 0.19044908, 0.01823341,
#            1.00799505],
#           [0.84716895, 0.7512297 , 0.61278041, ..., 0.19052025, 0.0182206 ,
#            1.00799348]]),
#    'std': array([[0.7357417 , 0.88984594, 0.63783147, ..., 0.73405129, 1.05240348,
#            0.00568408],
#           [0.73574639, 0.8897935 , 0.63778853, ..., 0.58468669, 0.80488266,
#            0.00568458],
#           [0.73571755, 0.88972417, 0.63775656, ..., 0.58822961, 0.80596576,
#            0.00570106],
#           ...,
#           [0.73575887, 0.88982852, 0.63785321, ..., 0.73899168, 1.05450522,
#            0.00567985],
#           [0.73574011, 0.88978045, 0.63784395, ..., 0.73612542, 1.05313284,
#            0.0056803 ],
#           [0.73571108, 0.88972126, 0.63780891, ..., 0.7353244 , 1.05316855,
#            0.00567229]])}},
#  {'kmeans': {'labels': array([1, 1, 1, ..., 1, 1, 1], dtype=int32),
#    'clustering': KMeans(n_clusters=2, random_state=42),
#    'eval_metrics': {'silhouette_score': np.float64(0.44866787959039056),
#     'davies_bouldin_score': np.float64(0.9673588247187358),
#     'calinski_harabasz_score': np.float64(88454.45467305953)},
#    'indices': array([409973, 183199,  75672, ..., 182387,  25003, 147839], dtype=int32)},
#   'gmm': {'labels': array([0, 0, 1, ..., 0, 0, 0]),
#    'clustering': GaussianMixture(n_components=2, random_state=42),
#    'eval_metrics': {'silhouette_score': np.float64(0.2777544008912352),
#     'davies_bouldin_score': np.float64(6.300263028927855),
#     'calinski_harabasz_score': np.float64(2346.2189427702697)},
#    'indices': array([409973, 183199,  75672, ..., 182387,  25003, 147839], dtype=int32)}},
#  {np.int64(0): 1,
#   np.int64(1): 1,
#   np.int64(2): 1,
#   np.int64(3): 1,
#   np.int64(4): 1,
#   np.int64(5): 1,
#   np.int64(6): 1,
#   np.int64(7): 1,
#   np.int64(8): 1,
#   np.int64(9): 1,
#   np.int64(10): 1,
#   np.int64(11): 1,
#   np.int64(12): 1,
#   np.int64(13): 1,
#   np.int64(14): 1,
#   np.int64(15): 1,
#   np.int64(16): 1,
#   np.int64(17): 1,
#   np.int64(18): 1,
#   np.int64(19): 1,
#   np.int64(20): 1,
#   np.int64(21): 1,
#   np.int64(22): 1,
#   np.int64(23): 1,
#   np.int64(24): 1,
#   np.int64(25): 1,
#   np.int64(26): 1,
#   np.int64(27): 1,
#   np.int64(28): 1,
#   np.int64(29): 1,
#   np.int64(30): 1,
#   np.int64(31): 1,
#   np.int64(32): 1,
#   np.int64(33): 1,
#   np.int64(34): 1,
#   np.int64(35): 1,
#   np.int64(36): 1,
#   np.int64(37): 1,
#   np.int64(38): 1,
#   np.int64(39): 1,
#   np.int64(40): 1,
#   np.int64(41): 1,
#   np.int64(42): 1,
#   np.int64(43): 1,
#   np.int64(44): 1,
#   np.int64(45): 1,
#   np.int64(46): 1,
#   np.int64(47): 1,
#   np.int64(48): 1,
#   np.int64(49): 1,
#   np.int64(50): 1,
#   np.int64(51): 1,
#   np.int64(52): 1,
#   np.int64(53): 1,
#   np.int64(54): 1,
#   np.int64(55): 1,
#   np.int64(56): 1,
#   np.int64(57): 1,
#   np.int64(58): 1,
#   np.int64(59): 1,
#   np.int64(60): 1,
#   np.int64(61): 1,
#   np.int64(62): 1,
#   np.int64(63): 1,
#   np.int64(64): 1,
#   np.int64(65): 1,
#   np.int64(66): 1,
#   np.int64(67): 1,
#   np.int64(68): 1,
#   np.int64(69): 1,
#   np.int64(70): 1,
#   np.int64(71): 1,
#   np.int64(72): 1,
#   np.int64(73): 1,
#   np.int64(74): 1,
#   np.int64(75): 1,
#   np.int64(76): 1,
#   np.int64(77): 1,
#   np.int64(78): 1,
#   np.int64(79): 1,
#   np.int64(80): 1,
#   np.int64(81): 1,
#   np.int64(82): 1,
#   np.int64(83): 1,
#   np.int64(84): 1,
#   np.int64(85): 1,
#   np.int64(86): 1,
#   np.int64(87): 1,
#   np.int64(88): 1,
#   np.int64(89): 1,
#   np.int64(90): 1,
#   np.int64(91): 1,
#   np.int64(92): 1,
#   np.int64(93): 1,
#   np.int64(94): 1,
#   np.int64(95): 1,
#   np.int64(96): 1,
#   np.int64(97): 1,
#   np.int64(98): 1,
#   np.int64(99): 1,
#   np.int64(100): 1,
#   np.int64(101): 1,
#   np.int64(102): 1,
#   np.int64(103): 1,
#   np.int64(104): 1,
#   np.int64(105): 1,
#   np.int64(106): 1,
#   np.int64(107): 1,
#   np.int64(108): 1,
#   np.int64(109): 1,
#   np.int64(110): 1,
#   np.int64(111): 1,
#   np.int64(112): 1,
#   np.int64(113): 1,
#   np.int64(114): 1,
#   np.int64(115): 1,
#   np.int64(116): 1,
#   np.int64(117): 1,
#   np.int64(118): 1,
#   np.int64(119): 1,
#   np.int64(120): 1,
#   np.int64(121): 1,
#   np.int64(122): 1,
#   np.int64(123): 1,
#   np.int64(124): 1,
#   np.int64(125): 1,
#   np.int64(126): 1,
#   np.int64(127): 1,
#   np.int64(128): 1,
#   np.int64(129): 1,
#   np.int64(130): 1,
#   np.int64(131): 1,
#   np.int64(132): 1,
#   np.int64(133): 1,
#   np.int64(134): 1,
#   np.int64(135): 1,
#   np.int64(136): 1,
#   np.int64(137): 1,
#   np.int64(138): 1,
#   np.int64(139): 1,
#   np.int64(140): 1,
#   np.int64(141): 1,
#   np.int64(142): 1,
#   np.int64(143): 1,
#   np.int64(144): 1,
#   np.int64(145): 1,
#   np.int64(146): 1,
#   np.int64(147): 1,
#   np.int64(148): 1,
#   np.int64(149): 1,
#   np.int64(150): 1,
#   np.int64(151): 1,
#   np.int64(152): 1,
#   np.int64(153): 1,
#   np.int64(154): 1,
#   np.int64(155): 1,
#   np.int64(156): 1,
#   np.int64(157): 1,
#   np.int64(158): 1,
#   np.int64(159): 1,
#   np.int64(160): 1,
#   np.int64(161): 1,
#   np.int64(162): 1,
#   np.int64(163): 1,
#   np.int64(164): 1,
#   np.int64(165): 1,
#   np.int64(166): 1,
#   np.int64(167): 1,
#   np.int64(168): 1,
#   np.int64(169): 1,
#   np.int64(170): 1,
#   np.int64(171): 1,
#   np.int64(172): 1,
#   np.int64(173): 1,
#   np.int64(174): 1,
#   np.int64(175): 1,
#   np.int64(176): 1,
#   np.int64(177): 1,
#   np.int64(178): 1,
#   np.int64(179): 1,
#   np.int64(180): 1,
#   np.int64(181): 1,
#   np.int64(182): 1,
#   np.int64(183): 1,
#   np.int64(184): 1,
#   np.int64(185): 1,
#   np.int64(186): 1,
#   np.int64(187): 1,
#   np.int64(188): 1,
#   np.int64(189): 1,
#   np.int64(190): 1,
#   np.int64(191): 1,
#   np.int64(192): 1,
#   np.int64(193): 1,
#   np.int64(194): 1,
#   np.int64(195): 1,
#   np.int64(196): 1,
#   np.int64(197): 1,
#   np.int64(198): 1,
#   np.int64(199): 1,
#   np.int64(200): 1,
#   np.int64(201): 1,
#   np.int64(202): 1,
#   np.int64(203): 1,
#   np.int64(204): 1,
#   np.int64(205): 1,
#   np.int64(206): 1,
#   np.int64(207): 1,
#   np.int64(208): 1,
#   np.int64(209): 1,
#   np.int64(210): 1,
#   np.int64(211): 1,
#   np.int64(212): 1,
#   np.int64(213): 1,
#   np.int64(214): 1,
#   np.int64(215): 1,
#   np.int64(216): 1,
#   np.int64(217): 1,
#   np.int64(218): 1,
#   np.int64(219): 1,
#   np.int64(220): 1,
#   np.int64(221): 1,
#   np.int64(222): 1,
#   np.int64(223): 1,
#   np.int64(224): 1,
#   np.int64(225): 1,
#   np.int64(226): 1,
#   np.int64(227): 1,
#   np.int64(228): 1,
#   np.int64(229): 1,
#   np.int64(230): 1,
#   np.int64(231): 1,
#   np.int64(232): 1,
#   np.int64(233): 1,
#   np.int64(234): 1,
#   np.int64(235): 1,
#   np.int64(236): 1,
#   np.int64(237): 1,
#   np.int64(238): 1,
#   np.int64(239): 1,
#   np.int64(240): 1,
#   np.int64(241): 1,
#   np.int64(242): 1,
#   np.int64(243): 1,
#   np.int64(244): 1,
#   np.int64(245): 1,
#   np.int64(246): 1,
#   np.int64(247): 1,
#   np.int64(248): 1,
#   np.int64(249): 1,
#   np.int64(250): 1,
#   np.int64(251): 1,
#   np.int64(252): 1,
#   np.int64(253): 1,
#   np.int64(254): 1,
#   np.int64(255): 1,
#   np.int64(256): 1,
#   np.int64(257): 1,
#   np.int64(258): 1,
#   np.int64(259): 1,
#   np.int64(260): 1,
#   np.int64(261): 1,
#   np.int64(262): 1,
#   np.int64(263): 1,
#   np.int64(264): 1,
#   np.int64(265): 1,
#   np.int64(266): 1,
#   np.int64(267): 1,
#   np.int64(268): 1,
#   np.int64(269): 1,
#   np.int64(270): 1,
#   np.int64(271): 1,
#   np.int64(272): 1,
#   np.int64(273): 1,
#   np.int64(274): 1,
#   np.int64(275): 1,
#   np.int64(276): 1,
#   np.int64(277): 1,
#   np.int64(278): 1,
#   np.int64(279): 1,
#   np.int64(280): 1,
#   np.int64(281): 1,
#   np.int64(282): 1,
#   np.int64(283): 1,
#   np.int64(284): 1,
#   np.int64(285): 1,
#   np.int64(286): 1,
#   np.int64(287): 1,
#   np.int64(288): 1,
#   np.int64(289): 1,
#   np.int64(290): 1,
#   np.int64(291): 1,
#   np.int64(292): 1,
#   np.int64(293): 1,
#   np.int64(294): 1,
#   np.int64(295): 1,
#   np.int64(296): 1,
#   np.int64(297): 1,
#   np.int64(298): 1,
#   np.int64(299): 1,
#   np.int64(300): 1,
#   np.int64(301): 1,
#   np.int64(302): 1,
#   np.int64(303): 1,
#   np.int64(304): 1,
#   np.int64(305): 1,
#   np.int64(306): 1,
#   np.int64(307): 1,
#   np.int64(308): 1,
#   np.int64(309): 1,
#   np.int64(310): 1,
#   np.int64(311): 1,
#   np.int64(312): 1,
#   np.int64(313): 1,
#   np.int64(314): 1,
#   np.int64(315): 1,
#   np.int64(316): 1,
#   np.int64(317): 1,
#   np.int64(318): 1,
#   np.int64(319): 1,
#   np.int64(320): 1,
#   np.int64(321): 1,
#   np.int64(322): 1,
#   np.int64(323): 1,
#   np.int64(324): 1,
#   np.int64(325): 1,
#   np.int64(326): 1,
#   np.int64(327): 1,
#   np.int64(328): 1,
#   np.int64(329): 1,
#   np.int64(330): 1,
#   np.int64(331): 1,
#   np.int64(332): 1,
#   np.int64(333): 1,
#   np.int64(334): 1,
#   np.int64(335): 1,
#   np.int64(336): 1,
#   np.int64(337): 1,
#   np.int64(338): 1,
#   np.int64(339): 1,
#   np.int64(340): 1,
#   np.int64(341): 1,
#   np.int64(342): 1,
#   np.int64(343): 1,
#   np.int64(344): 1,
#   np.int64(345): 1,
#   np.int64(346): 1,
#   np.int64(347): 1,
#   np.int64(348): 1,
#   np.int64(349): 1,
#   np.int64(350): 1,
#   np.int64(351): 1,
#   np.int64(352): 1,
#   np.int64(353): 1,
#   np.int64(354): 1,
#   np.int64(355): 1,
#   np.int64(356): 1,
#   np.int64(357): 1,
#   np.int64(358): 1,
#   np.int64(359): 1,
#   np.int64(360): 1,
#   np.int64(361): 1,
#   np.int64(362): 1,
#   np.int64(363): 1,
#   np.int64(364): 1,
#   np.int64(365): 1,
#   np.int64(366): 1,
#   np.int64(367): 1,
#   np.int64(368): 1,
#   np.int64(369): 1,
#   np.int64(370): 1,
#   np.int64(371): 1,
#   np.int64(372): 1,
#   np.int64(373): 1,
#   np.int64(374): 1,
#   np.int64(375): 1,
#   np.int64(376): 1,
#   np.int64(377): 1,
#   np.int64(378): 1,
#   np.int64(379): 1,
#   np.int64(380): 1,
#   np.int64(381): 1,
#   np.int64(382): 1,
#   np.int64(383): 1,
#   np.int64(384): 1,
#   np.int64(385): 1,
#   np.int64(386): 1,
#   np.int64(387): 1,
#   np.int64(388): 1,
#   np.int64(389): 1,
#   np.int64(390): 1,
#   np.int64(391): 1,
#   np.int64(392): 1,
#   np.int64(393): 1,
#   np.int64(394): 1,
#   np.int64(395): 1,
#   np.int64(396): 1,
#   np.int64(397): 1,
#   np.int64(398): 1,
#   np.int64(399): 1,
#   np.int64(400): 1,
#   np.int64(401): 1,
#   np.int64(402): 1,
#   np.int64(403): 1,
#   np.int64(404): 1,
#   np.int64(405): 1,
#   np.int64(406): 1,
#   np.int64(407): 1,
#   np.int64(408): 1,
#   np.int64(409): 1,
#   np.int64(410): 1,
#   np.int64(411): 1,
#   np.int64(412): 1,
#   np.int64(413): 1,
#   np.int64(414): 1,
#   np.int64(415): 1,
#   np.int64(416): 1,
#   np.int64(417): 1,
#   np.int64(418): 1,
#   np.int64(419): 1,
#   np.int64(420): 1,
#   np.int64(421): 1,
#   np.int64(422): 1,
#   np.int64(423): 1,
#   np.int64(424): 1,
#   np.int64(425): 1,
#   np.int64(426): 1,
#   np.int64(427): 1,
#   np.int64(428): 1,
#   np.int64(429): 1,
#   np.int64(430): 1,
#   np.int64(431): 1,
#   np.int64(432): 1,
#   np.int64(433): 1,
#   np.int64(434): 1,
#   np.int64(435): 1,
#   np.int64(436): 1,
#   np.int64(437): 1,
#   np.int64(438): 1,
#   np.int64(439): 1,
#   np.int64(440): 1,
#   np.int64(441): 1,
#   np.int64(442): 1,
#   np.int64(443): 1,
#   np.int64(444): 1,
#   np.int64(445): 1,
#   np.int64(446): 1,
#   np.int64(447): 1,
#   np.int64(448): 1,
#   np.int64(449): 1,
#   np.int64(450): 1,
#   np.int64(451): 1,
#   np.int64(452): 1,
#   np.int64(453): 1,
#   np.int64(454): 1,
#   np.int64(455): 1,
#   np.int64(456): 1,
#   np.int64(457): 1,
#   np.int64(458): 1,
#   np.int64(459): 1,
#   np.int64(460): 1,
#   np.int64(461): 1,
#   np.int64(462): 1,
#   np.int64(463): 1,
#   np.int64(464): 1,
#   np.int64(465): 1,
#   np.int64(466): 1,
#   np.int64(467): 1,
#   np.int64(468): 1,
#   np.int64(469): 1,
#   np.int64(470): 1,
#   np.int64(471): 1,
#   np.int64(472): 1,
#   np.int64(473): 1,
#   np.int64(474): 1,
#   np.int64(475): 1,
#   np.int64(476): 1,
#   np.int64(477): 1,
#   np.int64(478): 1,
#   np.int64(479): 1,
#   np.int64(480): 1,
#   np.int64(481): 1,
#   np.int64(482): 1,
#   np.int64(483): 1,
#   np.int64(484): 1,
#   np.int64(485): 1,
#   np.int64(486): 1,
#   np.int64(487): 1,
#   np.int64(488): 1,
#   np.int64(489): 1,
#   np.int64(490): 1,
#   np.int64(491): 1,
#   np.int64(492): 1,
#   np.int64(493): 1,
#   np.int64(494): 1,
#   np.int64(495): 1,
#   np.int64(496): 1,
#   np.int64(497): 1,
#   np.int64(498): 1,
#   np.int64(499): 1,
#   np.int64(500): 1,
#   np.int64(501): 1,
#   np.int64(502): 1,
#   np.int64(503): 1,
#   np.int64(504): 1,
#   np.int64(505): 1,
#   np.int64(506): 1,
#   np.int64(507): 1,
#   np.int64(508): 1,
#   np.int64(509): 1,
#   np.int64(510): 1,
#   np.int64(511): 1,
#   np.int64(512): 1,
#   np.int64(513): 1,
#   np.int64(514): 1,
#   np.int64(515): 1,
#   np.int64(516): 1,
#   np.int64(517): 1,
#   np.int64(518): 1,
#   np.int64(519): 1,
#   np.int64(520): 1,
#   np.int64(521): 1,
#   np.int64(522): 1,
#   np.int64(523): 1,
#   np.int64(524): 1,
#   np.int64(525): 1,
#   np.int64(526): 1,
#   np.int64(527): 1,
#   np.int64(528): 1,
#   np.int64(529): 1,
#   np.int64(530): 1,
#   np.int64(531): 1,
#   np.int64(532): 1,
#   np.int64(533): 1,
#   np.int64(534): 1,
#   np.int64(535): 1,
#   np.int64(536): 1,
#   np.int64(537): 1,
#   np.int64(538): 1,
#   np.int64(539): 1,
#   np.int64(540): 1,
#   np.int64(541): 1,
#   np.int64(542): 1,
#   np.int64(543): 1,
#   np.int64(544): 1,
#   np.int64(545): 1,
#   np.int64(546): 1,
#   np.int64(547): 1,
#   np.int64(548): 1,
#   np.int64(549): 1,
#   np.int64(550): 1,
#   np.int64(551): 1,
#   np.int64(552): 1,
#   np.int64(553): 1,
#   np.int64(554): 1,
#   np.int64(555): 1,
#   np.int64(556): 1,
#   np.int64(557): 1,
#   np.int64(558): 1,
#   np.int64(559): 1,
#   np.int64(560): 1,
#   np.int64(561): 1,
#   np.int64(562): 1,
#   np.int64(563): 1,
#   np.int64(564): 1,
#   np.int64(565): 1,
#   np.int64(566): 1,
#   np.int64(567): 1,
#   np.int64(568): 1,
#   np.int64(569): 1,
#   np.int64(570): 1,
#   np.int64(571): 1,
#   np.int64(572): 1,
#   np.int64(573): 1,
#   np.int64(574): 1,
#   np.int64(575): 1,
#   np.int64(576): 1,
#   np.int64(577): 1,
#   np.int64(578): 1,
#   np.int64(579): 1,
#   np.int64(580): 1,
#   np.int64(581): 1,
#   np.int64(582): 1,
#   np.int64(583): 1,
#   np.int64(584): 1,
#   np.int64(585): 1,
#   np.int64(586): 1,
#   np.int64(587): 1,
#   np.int64(588): 1,
#   np.int64(589): 1,
#   np.int64(590): 1,
#   np.int64(591): 1,
#   np.int64(592): 1,
#   np.int64(593): 1,
#   np.int64(594): 1,
#   np.int64(595): 1,
#   np.int64(596): 1,
#   np.int64(597): 1,
#   np.int64(598): 1,
#   np.int64(599): 1,
#   np.int64(600): 1,
#   np.int64(601): 1,
#   np.int64(602): 1,
#   np.int64(603): 1,
#   np.int64(604): 1,
#   np.int64(605): 1,
#   np.int64(606): 1,
#   np.int64(607): 1,
#   np.int64(608): 1,
#   np.int64(609): 1,
#   np.int64(610): 1,
#   np.int64(611): 1,
#   np.int64(612): 1,
#   np.int64(613): 1,
#   np.int64(614): 1,
#   np.int64(615): 1,
#   np.int64(616): 1,
#   np.int64(617): 1,
#   np.int64(618): 1,
#   np.int64(619): 1,
#   np.int64(620): 1,
#   np.int64(621): 1,
#   np.int64(622): 1,
#   np.int64(623): 1,
#   np.int64(624): 1,
#   np.int64(625): 1,
#   np.int64(626): 1,
#   np.int64(627): 1,
#   np.int64(628): 1,
#   np.int64(629): 1,
#   np.int64(630): 1,
#   np.int64(631): 1,
#   np.int64(632): 1,
#   np.int64(633): 1,
#   np.int64(634): 1,
#   np.int64(635): 1,
#   np.int64(636): 1,
#   np.int64(637): 1,
#   np.int64(638): 1,
#   np.int64(639): 1,
#   np.int64(640): 1,
#   np.int64(641): 1,
#   np.int64(642): 1,
#   np.int64(643): 1,
#   np.int64(644): 1,
#   np.int64(645): 1,
#   np.int64(646): 1,
#   np.int64(647): 1,
#   np.int64(648): 1,
#   np.int64(649): 1,
#   np.int64(650): 1,
#   np.int64(651): 1,
#   np.int64(652): 1,
#   np.int64(653): 1,
#   np.int64(654): 1,
#   np.int64(655): 1,
#   np.int64(656): 1,
#   np.int64(657): 1,
#   np.int64(658): 1,
#   np.int64(659): 1,
#   np.int64(660): 1,
#   np.int64(661): 1,
#   np.int64(662): 1,
#   np.int64(663): 1,
#   np.int64(664): 1,
#   np.int64(665): 1,
#   np.int64(666): 1,
#   np.int64(667): 1,
#   np.int64(668): 1,
#   np.int64(669): 1,
#   np.int64(670): 1,
#   np.int64(671): 1,
#   np.int64(672): 1,
#   np.int64(673): 1,
#   np.int64(674): 1,
#   np.int64(675): 1,
#   np.int64(676): 1,
#   np.int64(677): 1,
#   np.int64(678): 1,
#   np.int64(679): 1,
#   np.int64(680): 1,
#   np.int64(681): 1,
#   np.int64(682): 1,
#   np.int64(683): 1,
#   np.int64(684): 1,
#   np.int64(685): 1,
#   np.int64(686): 1,
#   np.int64(687): 1,
#   np.int64(688): 1,
#   np.int64(689): 1,
#   np.int64(690): 1,
#   np.int64(691): 1,
#   np.int64(692): 1,
#   np.int64(693): 1,
#   np.int64(694): 1,
#   np.int64(695): 1,
#   np.int64(696): 1,
#   np.int64(697): 1,
#   np.int64(698): 1,
#   np.int64(699): 1,
#   np.int64(700): 1,
#   np.int64(701): 1,
#   np.int64(702): 1,
#   np.int64(703): 1,
#   np.int64(704): 1,
#   np.int64(705): 1,
#   np.int64(706): 1,
#   np.int64(707): 1,
#   np.int64(708): 1,
#   np.int64(709): 1,
#   np.int64(710): 1,
#   np.int64(711): 1,
#   np.int64(712): 1,
#   np.int64(713): 1,
#   np.int64(714): 1,
#   np.int64(715): 1,
#   np.int64(716): 1,
#   np.int64(717): 1,
#   np.int64(718): 1,
#   np.int64(719): 1,
#   np.int64(720): 1,
#   np.int64(721): 1,
#   np.int64(722): 1,
#   np.int64(723): 1,
#   np.int64(724): 1,
#   np.int64(725): 1,
#   np.int64(726): 1,
#   np.int64(727): 1,
#   np.int64(728): 1,
#   np.int64(729): 1,
#   np.int64(730): 1,
#   np.int64(731): 1,
#   np.int64(732): 1,
#   np.int64(733): 1,
#   np.int64(734): 1,
#   np.int64(735): 1,
#   np.int64(736): 1,
#   np.int64(737): 1,
#   np.int64(738): 1,
#   np.int64(739): 1,
#   np.int64(740): 1,
#   np.int64(741): 1,
#   np.int64(742): 1,
#   np.int64(743): 1,
#   np.int64(744): 1,
#   np.int64(745): 1,
#   np.int64(746): 1,
#   np.int64(747): 1,
#   np.int64(748): 1,
#   np.int64(749): 1,
#   np.int64(750): 1,
#   np.int64(751): 1,
#   np.int64(752): 1,
#   np.int64(753): 1,
#   np.int64(754): 1,
#   np.int64(755): 1,
#   np.int64(756): 1,
#   np.int64(757): 1,
#   np.int64(758): 1,
#   np.int64(759): 1,
#   np.int64(760): 1,
#   np.int64(761): 1,
#   np.int64(762): 1,
#   np.int64(763): 1,
#   np.int64(764): 1,
#   np.int64(765): 1,
#   np.int64(766): 1,
#   np.int64(767): 1,
#   np.int64(768): 1,
#   np.int64(769): 1,
#   np.int64(770): 1,
#   np.int64(771): 1,
#   np.int64(772): 1,
#   np.int64(773): 1,
#   np.int64(774): 1,
#   np.int64(775): 1,
#   np.int64(776): 1,
#   np.int64(777): 1,
#   np.int64(778): 1,
#   np.int64(779): 1,
#   np.int64(780): 1,
#   np.int64(781): 1,
#   np.int64(782): 1,
#   np.int64(783): 1,
#   np.int64(784): 1,
#   np.int64(785): 1,
#   np.int64(786): 1,
#   np.int64(787): 1,
#   np.int64(788): 1,
#   np.int64(789): 1,
#   np.int64(790): 1,
#   np.int64(791): 1,
#   np.int64(792): 1,
#   np.int64(793): 1,
#   np.int64(794): 1,
#   np.int64(795): 1,
#   np.int64(796): 1,
#   np.int64(797): 1,
#   np.int64(798): 1,
#   np.int64(799): 1,
#   np.int64(800): 1,
#   np.int64(801): 1,
#   np.int64(802): 1,
#   np.int64(803): 1,
#   np.int64(804): 1,
#   np.int64(805): 1,
#   np.int64(806): 1,
#   np.int64(807): 1,
#   np.int64(808): 1,
#   np.int64(809): 1,
#   np.int64(810): 1,
#   np.int64(811): 1,
#   np.int64(812): 1,
#   np.int64(813): 1,
#   np.int64(814): 1,
#   np.int64(815): 1,
#   np.int64(816): 1,
#   np.int64(817): 1,
#   np.int64(818): 1,
#   np.int64(819): 1,
#   np.int64(820): 1,
#   np.int64(821): 1,
#   np.int64(822): 1,
#   np.int64(823): 1,
#   np.int64(824): 1,
#   np.int64(825): 1,
#   np.int64(826): 1,
#   np.int64(827): 1,
#   np.int64(828): 1,
#   np.int64(829): 1,
#   np.int64(830): 1,
#   np.int64(831): 1,
#   np.int64(832): 1,
#   np.int64(833): 1,
#   np.int64(834): 1,
#   np.int64(835): 1,
#   np.int64(836): 1,
#   np.int64(837): 1,
#   np.int64(838): 1,
#   np.int64(839): 1,
#   np.int64(840): 1,
#   np.int64(841): 1,
#   np.int64(842): 1,
#   np.int64(843): 1,
#   np.int64(844): 1,
#   np.int64(845): 1,
#   np.int64(846): 1,
#   np.int64(847): 1,
#   np.int64(848): 1,
#   np.int64(849): 1,
#   np.int64(850): 1,
#   np.int64(851): 1,
#   np.int64(852): 1,
#   np.int64(853): 1,
#   np.int64(854): 1,
#   np.int64(855): 1,
#   np.int64(856): 1,
#   np.int64(857): 1,
#   np.int64(858): 1,
#   np.int64(859): 1,
#   np.int64(860): 1,
#   np.int64(861): 1,
#   np.int64(862): 1,
#   np.int64(863): 1,
#   np.int64(864): 1,
#   np.int64(865): 1,
#   np.int64(866): 1,
#   np.int64(867): 1,
#   np.int64(868): 1,
#   np.int64(869): 1,
#   np.int64(870): 1,
#   np.int64(871): 1,
#   np.int64(872): 1,
#   np.int64(873): 1,
#   np.int64(874): 1,
#   np.int64(875): 1,
#   np.int64(876): 1,
#   np.int64(877): 1,
#   np.int64(878): 1,
#   np.int64(879): 1,
#   np.int64(880): 1,
#   np.int64(881): 1,
#   np.int64(882): 1,
#   np.int64(883): 1,
#   np.int64(884): 1,
#   np.int64(885): 1,
#   np.int64(886): 1,
#   np.int64(887): 1,
#   np.int64(888): 1,
#   np.int64(889): 1,
#   np.int64(890): 1,
#   np.int64(891): 1,
#   np.int64(892): 1,
#   np.int64(893): 1,
#   np.int64(894): 1,
#   np.int64(895): 1,
#   np.int64(896): 1,
#   np.int64(897): 1,
#   np.int64(898): 1,
#   np.int64(899): 1,
#   np.int64(900): 1,
#   np.int64(901): 1,
#   np.int64(902): 1,
#   np.int64(903): 1,
#   np.int64(904): 1,
#   np.int64(905): 1,
#   np.int64(906): 1,
#   np.int64(907): 1,
#   np.int64(908): 1,
#   np.int64(909): 1,
#   np.int64(910): 1,
#   np.int64(911): 1,
#   np.int64(912): 1,
#   np.int64(913): 1,
#   np.int64(914): 1,
#   np.int64(915): 1,
#   np.int64(916): 1,
#   np.int64(917): 1,
#   np.int64(918): 1,
#   np.int64(919): 1,
#   np.int64(920): 1,
#   np.int64(921): 1,
#   np.int64(922): 1,
#   np.int64(923): 1,
#   np.int64(924): 1,
#   np.int64(925): 1,
#   np.int64(926): 1,
#   np.int64(927): 1,
#   np.int64(928): 1,
#   np.int64(929): 1,
#   np.int64(930): 1,
#   np.int64(931): 1,
#   np.int64(932): 1,
#   np.int64(933): 1,
#   np.int64(934): 1,
#   np.int64(935): 1,
#   np.int64(936): 1,
#   np.int64(937): 1,
#   np.int64(938): 1,
#   np.int64(939): 1,
#   np.int64(940): 1,
#   np.int64(941): 1,
#   np.int64(942): 1,
#   np.int64(943): 1,
#   np.int64(944): 1,
#   np.int64(945): 1,
#   np.int64(946): 1,
#   np.int64(947): 1,
#   np.int64(948): 1,
#   np.int64(949): 1,
#   np.int64(950): 1,
#   np.int64(951): 1,
#   np.int64(952): 1,
#   np.int64(953): 1,
#   np.int64(954): 1,
#   np.int64(955): 1,
#   np.int64(956): 1,
#   np.int64(957): 1,
#   np.int64(958): 1,
#   np.int64(959): 1,
#   np.int64(960): 1,
#   np.int64(961): 1,
#   np.int64(962): 1,
#   np.int64(963): 1,
#   np.int64(964): 1,
#   np.int64(965): 1,
#   np.int64(966): 1,
#   np.int64(967): 1,
#   np.int64(968): 1,
#   np.int64(969): 1,
#   np.int64(970): 1,
#   np.int64(971): 1,
#   np.int64(972): 1,
#   np.int64(973): 1,
#   np.int64(974): 1,
#   np.int64(975): 1,
#   np.int64(976): 1,
#   np.int64(977): 1,
#   np.int64(978): 1,
#   np.int64(979): 1,
#   np.int64(980): 1,
#   np.int64(981): 1,
#   np.int64(982): 1,
#   np.int64(983): 1,
#   np.int64(984): 1,
#   np.int64(985): 1,
#   np.int64(986): 1,
#   np.int64(987): 1,
#   np.int64(988): 1,
#   np.int64(989): 1,
#   np.int64(990): 1,
#   np.int64(991): 1,
#   np.int64(992): 1,
#   np.int64(993): 1,
#   np.int64(994): 1,
#   np.int64(995): 1,
#   np.int64(996): 1,
#   np.int64(997): 1,
#   np.int64(998): 1,
#   np.int64(999): 1,
#   ...})

# %%
data_path = '../data'
output_dir='./models/clustering'
bundle_size=30
step_size=15
reducer_method='umap'
use_gpu=True,
cluster_methods=['kmeans','gmm']


# Create output directory
os.makedirs(output_dir, exist_ok=True)

# Step 1: Load the data
print("\nStep 1: Loading EEG data...")
if os.path.isdir(data_path):
    file_dfs, combined_df = load_eeg_data(directory_path=data_path)
else:
    file_dfs, combined_df = load_eeg_data(single_file=data_path)

# Step 2: Preprocess and engineer features for each file
print("\nStep 2: Preprocessing and feature engineering...")
processed_dfs = {}

for file_id, df in file_dfs.items():
    # Preprocess
    df_clean = preprocess_eeg_data(df)
    
    # Engineer features
    df_features = engineer_eeg_features(df_clean)
    
    processed_dfs[file_id] = df_features

# Step 3: Create coherent time series bundles
print("\nStep 3: Creating time series bundles...")
X_bundles, metadata = create_coherent_time_series_bundles(
    file_dfs=processed_dfs,
    bundle_size=bundle_size,
    step_size=step_size
)

# %%
# Step 4: Normalize bundles
print("\nStep 4: Normalizing bundles...")
X_normalized = normalize_bundles(X_bundles, normalization='per_feature')

# Step 5: Reduce dimensions for visualization
print("\nStep 5: Reducing dimensions with " + reducer_method.upper() + "...")
# Flatten time dimension by taking mean across time steps
X_flat = X_normalized.mean(axis=1) if X_normalized.ndim == 3 else X_normalized
X_reduced, reducer = reduce_dimensions(
    X_flat, method=reducer_method, n_components=2, use_gpu=use_gpu
)

# Save the reducer
try:
    joblib.dump(reducer, os.path.join(output_dir, f'{reducer_method}_reducer.joblib'))
except:
    print(f"Warning: Could not save the {reducer_method} reducer. It may not be serializable.")

# Step 6: Cluster the data
print("\nStep 6: Clustering data...")
clustering_results = cluster_data(
    X_flat, X_reduced, methods=cluster_methods, n_clusters=2, use_gpu=use_gpu
)

# Step 7: Analyze cluster characteristics
print("\nStep 7: Analyzing cluster characteristics...")
# Find the best clustering method based on silhouette score
best_method = max(
    clustering_results,
    key=lambda m: clustering_results[m]['eval_metrics']['silhouette_score'] or -1
)

print(f"\nBest clustering method: {best_method}")

# Analyze the best clustering
best_labels = clustering_results[best_method]['labels']

# Get feature names if they are in metadata
if X_normalized.ndim == 3:
    # These are generic feature names since we flattened the time dimension
    feature_names = [f'Feature_{i}' for i in range(X_flat.shape[1])]
else:
    feature_names = None

cluster_profiles = analyze_cluster_characteristics(
    X_normalized, best_labels, feature_names
)

# Save the best clustering model
try:
    joblib.dump(
        clustering_results[best_method]['clustering'],
        os.path.join(output_dir, f'{best_method}_clustering.joblib')
    )
    
    # Save labels for later use
    np.save(os.path.join(output_dir, 'cluster_labels.npy'), best_labels)
    
    # Save metadata with cluster labels
    metadata_with_clusters = metadata.copy()
    metadata_with_clusters['cluster'] = best_labels
    metadata_with_clusters.to_csv(os.path.join(output_dir, 'metadata_with_clusters.csv'), index=False)
    
except Exception as e:
    print(f"Warning: Could not save clustering results. Error: {e}")

results = {
    'X_bundles': X_bundles,
    'X_normalized': X_normalized,
    'X_reduced': X_reduced,
    'metadata': metadata,
    'clustering_results': clustering_results,
    'best_method': best_method,
    'cluster_profiles': cluster_profiles
}

# %%
df.head()

# %%
# 1. Run the unsupervised learning pipeline
results = unsupervised_learning_pipeline(df, output_dir='./models')

# 2. Later, apply clustering to new data
# new_labels = apply_clustering_to_new_data(
#     new_data,
#     model_path='models/clustering_model_kmeans.joblib',
#     feature_path='models/selected_features_unsupervised.txt',
#     reducer_path='models/umap_reducer.joblib'
# )

# 3. Analyze the distribution of clusters in new data
# print(f"Percentage in cluster 0 (likely relaxed): {(new_labels == 0).mean() * 100:.2f}%")
# print(f"Percentage in cluster 1 (likely focused): {(new_labels == 1).mean() * 100:.2f}%")
